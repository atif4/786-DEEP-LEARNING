# %% [markdown]
# # Chapter # 01

# %% [raw]
# - perception("the ability to see, hear, or become aware of something through the senses:") problem: is solved by deep Learning
# - every DL and ML model find the best suitable values of w & b(w & b are parameters/weights) and those values are in
#             relationship it might be statistical_structure
# - hypothesis testing, conditional probability, and disturbution these 3 thing are very useful for ML and DL.
# - Maths theory is used very less in DL
# - Machine needs 3 things to represent data 1st is input-data, output_label and loss (feedback signal->goes to optimazer and
#             plot that loss in xyz demensions then take slop and on the bases of slope the weights are arrange.
#             if the slop is -ve your weight will update +vely if it is +ve your weights will update -vely)
# - loss = actual value - predicted value
# - learning reperenation: find the specific pattern b/w data-points .
# - learning means transformation
# - transformation means change the data from one form to another
# - transformation done by predefine hypothesis space
# - Hyper parameter: optimizer, loss function, no of layers, no of input, no of output, activation_function, which activation                 function apply on every layer, and which function apply on last layer these are called hyper parameters.
# - the complete physicaly and digitially sturcture of how many input and output layers is called hypothesis space.
# - hypothesis space is a predefined structure of your network or predefined set of operations such a no of layers,
# - physicaly structure means when data load in memory activation function, loss function called a hypothesis space.
# - deep Learning: deep means no of layers as you increase no of layers/hidden layers your model/network becomes deeper and                   deeper (it 'may be' called layers represention learning b/c it goes to 1 to another leyer respectively or                               hierarchical representations learning)
# - shallow learning problem : is solve by machine learning (random forest). it also has layers but they are limited such 2 to 3             only. and every layer does different learning however deep Learning has 10 or 1000 layers and they learn jointly

# %%
import matplotlib.pyplot as plt
import cv2
file_name = "workflow.png"
image = cv2.imread(file_name)
plt.imshow(image)
plt.show()
image.shape
# Out:
# (371, 351, 3)

# %% [raw]
# - Image shows that your input goes to 1st layer afterward it multipliced by w and b then the previous data transform into a
#             new data then the new datapoint goes to respective layer and over there w and b applied on it as well,
#             transformation occure b/c w & b, and in deep Learning we try to find correct value of w & b and on the last we
#             get result which is prediction and on 1st time prediction would be wrong b/c random value of w & b the values might
#             be behind the zero_point(0)  or befor zero_point(0) and we need th3 values zero or nearer to zero. this whole process is called forward propagation

# %%
image = cv2.imread('work flow ch 1.png')
plt.imshow(image)
plt.show()

# %%
- So we take the loss by actual value - predicted value then we get the difference b/w them then we take derivative Slope if
            the slop of derivate is +ve then we update the values of w and b in -ve direction and if slop of derivate is -ve 
            then we update the values of w and b in +ve direction 
- So at start our prog: we gave inputs as X and answers as y which called True_label\actual_value.

# %%
image = cv2.imread('wfc1.png')
plt.imshow(image)
plt.show()

# %% [raw]
# - Once you get loss(feedback signal) then optimizer decides which direction it should move the weights when it update
#             weights again, this process is called backward propagation. and once again the whole process repates again to
#             decrease the loss to lostest point or near to it and increase the accuracy

# %%
image = cv2.imread('decision_boundary.png')
plt.imshow(image)
plt.show()

# %% [raw]
# - KERNEL METHODS: we have dataset in high dimensions and we need a line to seprate the different data-points from the dataset.
#         the line is called hyper_plane so put line/hyper_plane where it has maximum distance/margine from both sides.
#         then got a decision boundary.
# - Function used to convert dataset from high dimension to another dimension is called kernel function or
#         the function you write to define a line or hyper_parameter is called kernel function  (SVM)

# %%
- gradient boosting ML: p(1) it convert week learner into strong learner

# %% [raw]
# - Regression: the process which learns to predict continuous value output for given input I,e predict price, length, width
# - 4 steps in DL Application:
# - 1) pre-processing: Data Refine, Category, Scaling
# - 2) Network Designing: neurons_height, neurons_width, activation_function, layers
# - 3) Hyper parameter Selection: optimizer, loss function
# - 4) Testing: over testing
# - neurons in Dense layers should be in even numbers such as 10, 12, 18, 22, 30 etc

# %% [raw]
# - numpy and tensor are equal
